# %%
import json
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
folder = "multi_untargeted"
file_pattern = os.path.join(folder, "results_multi_untargeted_*.json")
json_files = glob.glob(file_pattern)[:10]  # Take first 10 files if more exist

print(f"Found {len(json_files)} files:")
for file in json_files:
    print(file)
# Out:
# Found 10 files:
# multi_untargeted\results_multi_untargeted_20250724_185832.json
# multi_untargeted\results_multi_untargeted_20250724_185859.json
# multi_untargeted\results_multi_untargeted_20250724_185932.json
# multi_untargeted\results_multi_untargeted_20250724_190019.json
# multi_untargeted\results_multi_untargeted_20250724_190039.json
# multi_untargeted\results_multi_untargeted_20250724_190100.json
# multi_untargeted\results_multi_untargeted_20250724_190134.json
# multi_untargeted\results_multi_untargeted_20250724_190346.json
# multi_untargeted\results_multi_untargeted_20250724_190906.json
# multi_untargeted\results_multi_untargeted_20250724_190945.json

# %%
# Initialize data structures
all_iterations = set()  # Initialize as a set
data_by_iteration = defaultdict(list)  # Dictionary to store data by iteration

# Read and process each JSON file
for file_path in json_files:
    with open(file_path, 'r') as f:
        data = json.load(f)
    
    # Extract metrics over time
    metrics = data['metrics_over_time']
    
    # Create a dictionary of this file's data by iteration
    file_data = {entry['iterations']: entry for entry in metrics}
    
    # Update the set of all iterations we've seen
    all_iterations.update(file_data.keys())
    
    # For each iteration in this file, store its data
    for iteration, entry in file_data.items():
        data_by_iteration[iteration].append({
            'noise': entry['noise_magnitude'],
            'current_boxes': entry['current_boxes'],
            'original_boxes': entry['original_boxes'],
            'percentage_increase': entry['percentage_increase']
        })

# Convert to sorted list of iterations
sorted_iterations = sorted(all_iterations)

# %%
# Calculate average values for each iteration across files
avg_data = []
for iteration in sorted_iterations:
    entries = data_by_iteration[iteration]
    
    # Only calculate average if we have data from multiple files
    if len(entries) > 1:
        avg_noise = np.mean([e['noise'] for e in entries])
        avg_current_boxes = np.mean([e['current_boxes'] for e in entries])
        avg_percentage = np.mean([e['percentage_increase'] for e in entries])
        
        # Original boxes should be the same across all entries
        original_boxes = entries[0]['original_boxes']
        
        avg_data.append({
            'iteration': iteration,
            'avg_noise': avg_noise,
            'avg_current_boxes': avg_current_boxes,
            'avg_percentage': avg_percentage,
            'original_boxes': original_boxes,
            'num_files': len(entries)  # Track how many files contributed to this average
        })

# %%
# Create the plot
plt.figure(figsize=(12, 8))

# Create primary axis for noise and current boxes
ax1 = plt.gca()
ax2 = ax1.twinx()

# Plot average noise
ax1.plot([d['iteration'] for d in avg_data],
         [d['avg_noise'] for d in avg_data],
         'b-', label='Average Noise Magnitude', linewidth=2)

# Plot average current boxes
ax2.plot([d['iteration'] for d in avg_data],
         [d['avg_current_boxes'] for d in avg_data],
         'r-', label='Average Current Boxes', linewidth=2)

# Set labels and colors
ax1.set_xlabel('Iterations', fontsize=12)
ax1.set_ylabel('Noise Magnitude', color='b', fontsize=12)
ax2.set_ylabel('Current Boxes', color='r', fontsize=12)

# Add title
plt.title(f'Average Attack Metrics Across {len(json_files)} Runs', fontsize=14)

# Add legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

# Add grid
ax1.grid(True, linestyle='--', alpha=0.7)

# Add information box about original boxes and percentage increase
if avg_data:
    last_point = avg_data[-1]
    info_text = (f"Original Boxes: {last_point['original_boxes']}\n"
                 f"Final % Increase: {last_point['avg_percentage']:.1f}%\n"
                 f"Files averaged: {len(json_files)}")
    
    plt.annotate(info_text, xy=(0.9, 0.1), xycoords='axes fraction',
                 bbox=dict(boxstyle='round', facecolor='white', alpha=0.8),
                 fontsize=10)

# %%
# Adjust layout
plt.tight_layout()

# %%
# Show plot
plt.show()

# %%
# Show how many files contributed to each iteration average
print("\nData availability per iteration:")
for d in avg_data:
    print(f"Iteration {d['iteration']}: {d['num_files']} files")
# Out:
# Data availability per iteration:
# Iteration 1: 5 files
# Iteration 2: 5 files
# Iteration 3: 5 files
# Iteration 4: 5 files
# Iteration 5: 5 files
# Iteration 6: 5 files
# Iteration 7: 5 files
# Iteration 8: 5 files
# Iteration 9: 5 files
# Iteration 10: 5 files
# Iteration 11: 5 files
# Iteration 12: 5 files
# Iteration 13: 5 files
# Iteration 14: 5 files
# Iteration 15: 5 files
# Iteration 16: 5 files
# Iteration 17: 5 files
# Iteration 18: 5 files
# Iteration 19: 5 files
# Iteration 20: 5 files
# Iteration 21: 5 files
# Iteration 22: 5 files
# Iteration 23: 5 files
# Iteration 24: 5 files
# Iteration 25: 5 files
# Iteration 26: 5 files
# Iteration 27: 5 files
# Iteration 28: 5 files
# Iteration 29: 5 files
# Iteration 30: 5 files
# Iteration 31: 5 files
# Iteration 32: 5 files
# Iteration 33: 5 files
# Iteration 34: 5 files
# Iteration 35: 5 files
# Iteration 36: 5 files
# Iteration 37: 5 files
# Iteration 38: 5 files
# Iteration 39: 5 files
# Iteration 40: 5 files
# Iteration 41: 5 files
# Iteration 42: 5 files
# Iteration 43: 5 files
# Iteration 44: 5 files
# Iteration 45: 5 files
# Iteration 46: 5 files
# Iteration 47: 5 files
# Iteration 48: 5 files
# Iteration 49: 5 files
# Iteration 50: 5 files
# Iteration 51: 5 files
# Iteration 52: 5 files
# Iteration 53: 5 files
# Iteration 54: 5 files
# Iteration 55: 5 files
# Iteration 56: 5 files
# Iteration 57: 5 files
# Iteration 58: 5 files
# Iteration 59: 5 files
# Iteration 60: 5 files
# Iteration 61: 5 files
# Iteration 62: 5 files
# Iteration 63: 5 files
# Iteration 64: 5 files
# Iteration 65: 5 files
# Iteration 66: 5 files
# Iteration 67: 5 files
# Iteration 68: 5 files
# Iteration 69: 5 files
# Iteration 70: 5 files
# Iteration 71: 5 files
# Iteration 72: 5 files
# Iteration 73: 5 files
# Iteration 74: 5 files
# Iteration 75: 5 files
# Iteration 76: 5 files
# Iteration 77: 5 files
# Iteration 78: 5 files
# Iteration 79: 5 files
# Iteration 80: 5 files
# Iteration 81: 5 files
# Iteration 82: 5 files
# Iteration 83: 5 files
# Iteration 84: 5 files
# Iteration 85: 5 files
# Iteration 86: 5 files
# Iteration 87: 5 files
# Iteration 88: 5 files
# Iteration 89: 5 files
# Iteration 90: 5 files
# Iteration 91: 5 files
# Iteration 92: 5 files
# Iteration 93: 5 files
# Iteration 94: 5 files
# Iteration 95: 5 files
# Iteration 96: 5 files
# Iteration 97: 5 files
# Iteration 98: 5 files
# Iteration 99: 5 files
# Iteration 100: 5 files
# Iteration 101: 5 files
# Iteration 102: 5 files
# Iteration 103: 5 files
# Iteration 104: 5 files
# Iteration 105: 5 files
# Iteration 106: 5 files
# Iteration 107: 5 files
# Iteration 108: 5 files
# Iteration 109: 5 files
# Iteration 110: 5 files
# Iteration 111: 5 files
# Iteration 112: 5 files
# Iteration 113: 5 files
# Iteration 114: 5 files
# Iteration 115: 5 files
# Iteration 116: 5 files
# Iteration 117: 5 files
# Iteration 118: 5 files
# Iteration 119: 5 files
# Iteration 120: 5 files
# Iteration 121: 5 files
# Iteration 122: 5 files
# Iteration 123: 5 files
# Iteration 124: 5 files
# Iteration 125: 5 files
# Iteration 126: 5 files
# Iteration 127: 5 files
# Iteration 128: 5 files
# Iteration 129: 5 files
# Iteration 130: 5 files
# Iteration 131: 5 files
# Iteration 132: 5 files
# Iteration 133: 5 files
# Iteration 134: 5 files
# Iteration 135: 5 files
# Iteration 136: 5 files
# Iteration 137: 5 files
# Iteration 138: 5 files
# Iteration 139: 5 files
# Iteration 140: 5 files
# Iteration 141: 5 files
# Iteration 142: 5 files
# Iteration 143: 5 files
# Iteration 144: 5 files
# Iteration 145: 5 files
# Iteration 146: 5 files
# Iteration 147: 5 files
# Iteration 148: 5 files
# Iteration 149: 5 files
# Iteration 150: 5 files
# Iteration 151: 5 files
# Iteration 152: 5 files
# Iteration 153: 5 files
# Iteration 154: 5 files
# Iteration 155: 5 files
# Iteration 156: 5 files
# Iteration 157: 5 files
# Iteration 158: 5 files
# Iteration 159: 5 files
# Iteration 160: 5 files
# Iteration 161: 5 files
# Iteration 162: 5 files
# Iteration 163: 5 files
# Iteration 164: 5 files
# Iteration 165: 5 files
# Iteration 166: 5 files
# Iteration 167: 5 files
# Iteration 168: 5 files
# Iteration 169: 5 files
# Iteration 170: 5 files
# Iteration 171: 5 files
# Iteration 172: 5 files
# Iteration 173: 5 files
# Iteration 174: 5 files
# Iteration 175: 5 files
# Iteration 176: 5 files
# Iteration 177: 5 files
# Iteration 178: 5 files
# Iteration 179: 5 files
# Iteration 180: 5 files
# Iteration 181: 5 files
# Iteration 182: 5 files
# Iteration 183: 5 files
# Iteration 184: 5 files
# Iteration 185: 5 files
# Iteration 186: 5 files
# Iteration 187: 5 files
# Iteration 188: 5 files
# Iteration 189: 5 files
# Iteration 190: 5 files
# Iteration 191: 5 files
# Iteration 192: 5 files
# Iteration 193: 5 files
# Iteration 194: 5 files
# Iteration 195: 5 files
# Iteration 196: 5 files
# Iteration 197: 5 files
# Iteration 198: 5 files
# Iteration 199: 5 files
# Iteration 200: 10 files
